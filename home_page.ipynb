# %% [markdown]
# # Welcome to the Galaxy's GPU enabled Interactive Jupyterlab for Artificial intelligence (AI).

# %% [markdown]
# Jupyter notebook is powered by the latest JupyterLab, Tensorflow, Scikit-learn, Pandas, Numpy, Scipy, Seaborn, Matplotlib and many more which can be used to prototype and develop machine learning and deep learning solutions executing on Galaxy's NVIDIA GPUs.
# The docker container used can be found at [docker image](https://github.com/anuprulez/ml-jupyter-notebook/tree/galaxy-inte-docker-ml-jupyter).
#
# ## Core features
# - Run AI programs on **GPUs**
# - **Pre-installed** packages for AI
# - Integrated with **Git** version control
# - [Elyra AI](https://github.com/elyra-ai/elyra) **workflow** of notebooks
# - **Shareable** AI models via Open Neural Network Exchange ([ONNX](https://onnx.ai/))
# - Run **Galaxy tools** using [Bioblend APIs](https://bioblend.readthedocs.io/en/latest/index.html)
#
# ## How to use
# - Galaxy training network (GTN) [**tutorial**](https://training.galaxyproject.org/training-material/topics/statistics/tutorials/gpu_jupyter_lab/tutorial.html)

# %% [markdown]
# ## Introduction
#
# Jupyterlab notebooks are extremely popular with data scientists and researchers to explore datasets from multiple fields of studies and develop **prototypes**. The notebooks come integrated with a lots of packages such as NumPy, Statsmodel, Pandas, Scikit-learn, Tensorflow, Matplotlib which expedite prototyping and provide useful insights into the datasets. In a notebook, each rectangular box is known as a **cell** which executes **Python code** written in it.

# %%
a = 6
b = 10
c = a + b

# %% [markdown]
# Execute the above cell by clicking on "CTRL+Enter". Writing a variable such as "c" in a cell and executing it prints the output of that variable.

# %%
c
# Out:
# 16

# %% [markdown]
# ### Working with GPUs
#
# GPU computation is configured in this notebook via the docker image which allows deep learning programs runs much faster.

# %% [markdown]
# ### Data Science

# %% [markdown]
# The field of data science incorporates multiple tasks to understand a dataset such as **plotting** to visualize different features, **data manipulation** to impute missing values, finding **appropriate machine and deep learning algorithm** and many more. A few examples of two plotting libraries, [Matplotlib](https://matplotlib.org/) and [Seaborn](https://seaborn.pydata.org/), are shown below.

# %% [markdown]
# ### Plotting

# %% [markdown]
# #### Plot bar chart with Matplotlib library

# %%
### Source: https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py

import matplotlib.pyplot as plt
import numpy as np

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()

# %% [markdown]
# #### Scatterplot with Seaborn

# %%
# Source: https://seaborn.pydata.org/examples/scatterplot_matrix.html

import seaborn as sns
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %% [markdown]
# More examples of plotting can be found:
#
# - [Matplotlib plots](notebooks/plots_matplotlib.ipynb)
# - [Seaborn plots](notebooks/plots_seaborn.ipynb)
# - [bq plots](notebooks/bqplots.ipynb)

# %% [markdown]
# ### Data manipulation

# %% [markdown]
# Raw dataset should be preprocessed to remove impurities such as outliers, impute missing values, scale, normalize, remove dimensions and many more. Preprocessing gives a clean dataset to analyze meaningful correlations and aspects. One of the popular data manipulation  packages in Python is [Pandas](https://pandas.pydata.org/docs/index.html). It works with many file formats of datasets such as CSV, TSV, HDF5, HTML, JSON and so on.

# %%
# https://pandas.pydata.org/docs/getting_started/index.html

# Read a tabular dataset (TSV = tab separated values)
import pandas as pd
cancer_dataset = pd.read_csv("data/breast-w_test.tsv", sep="\t")

# %%
cancer_dataset
# Out:
#     Clump_Thickness  Cell_Size_Uniformity  Cell_Shape_Uniformity  \
# 0                 5                     2                      4
# 1                 3                     1                      1
# 2                 1                     1                      1
# 3                 4                     1                      1
# 4                 5                     4                      6
# ..              ...                   ...                    ...
# 95                3                     1                      1
# 96                2                     1                      1
# 97                5                    10                     10
# 98                4                     8                      6
# 99                4                     8                      8
#
#     Marginal_Adhesion  Single_Epi_Cell_Size  Bare_Nuclei  Bland_Chromatin  \
# 0                   1                     1            0                1
# ...

# %% [markdown]
# Some examples of Pandas can be found below
#
# - [Pandas](notebooks/pandas.ipynb)

# %% [markdown]
# ### Machine learning with Scikit learn
#
# [Scikit-learn](https://scikit-learn.org/stable/) package provides many algorithms for different types of machine learning tasks such as classification, regression, clustering, dimensionality reduction, data preprocessing, hyperparameter optimisation and many more. An example:

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0)
X = [[ 1,  2,  3],  # 2 samples, 3 features
     [11, 12, 13]]
y = [0, 1]  # classes of each sample

# fit a training model
clf.fit(X, y)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# predict on training data
clf.predict(X)

# predict on new data
clf.predict([[4, 5, 6], [14, 15, 16]])
# Out:
# array([0, 1])

# %% [markdown]
# ### Deep learning with Tensorflow
#
# [Tensorflow](https://www.tensorflow.org/) package provides a way to create deep learning models through multi-layer architectures with large datasets. These architectures can be used for many learning tasks such as classification, regression, dimensionality reduction, data imputation and many more. There are different architectures best suited for different datasets such as CNN for images, RNN for sequential datasets and so on. An example deep learning architecture is shown below.
#
# - [Deep learning with tensorflow](notebooks/tensorflow-deep-learning.ipynb)

# %% [markdown]
# ### Model sharing
#
# Machine learning algorithms create models after training which are used to predict on unseen datasets. These models contains information about multiple attributes of the learning algorithms such as weights, architecture, and so on. These models should be in a format so that it can be deployed to different machines and should not just work on the machine it has been created. To represent machine learning models and to make them reusable, [Open Neural Network Exchange](https://github.com/onnx/onnx) (ONNX) format provides a standard approach. Some examples of storing Scikit-learn and Tensorflow models as `.onnx` files are shown below:
#
# - [Model sharing](notebooks/model-sharing.ipynb)

# %% [markdown]
# ### Git version control
#
# Git version control is available with the notebook to create, pull and maintain code repositories from Github. Jupyterlab Git plugin, [jupyterlab-git](https://github.com/jupyterlab/jupyterlab-git), makes it possible to avail the features of a real version control system directly in the notebook.

# %% [markdown]
# ### Elyra AI workflow of notebooks

# %% [markdown]
# Using [Elyra AI](https://github.com/elyra-ai/elyra), workflows of jupyterlab notebooks can be created, saved and executed either locally or on remote machines using execution runtimes such as Kubeblow or Airflow. It allows a large analysis to be broken down into smaller, resuable notebooks and can be execute with one click. Worklfows can be created by dragging the notebooks on the workflow editor and then joining the blocks of notebooks. An example workflow is shown below and the associated notebooks and workflow (`.pipeline`) files are stored at `/elyra`.
#
# ![ElyraWorkflow](https://github.com/anuprulez/jupyterlab_notebooks/raw/main/features_notebooks/images/elyra_pipeline.png)

# %% [markdown]
# ### Access Bioblend APIs

# %% [markdown]
# Using Bioblend APIs, many features such as tools, histories, workflows can be accessed in Galaxy. In this notebook, Bioblend APIs are pre-installed to communicate
# with Galaxy server by providing its URL. In the following example notebook, a few examples are shown to establish communication with Galaxy history. For example, using `put` function, any dataset can be pushed to Galaxy history.

# %% [markdown]
# - [Bioblend APIs](notebooks/bioblend_APIs.ipynb)
